# %%
import pandas as pd
from geopy import geocoders

# %%
df = pd.read_csv("Toronto.csv", index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 3 columns):
# Postcode         103 non-null object
# Borough          103 non-null object
# Neighbourhood    103 non-null object
# dtypes: object(3)
# memory usage: 3.2+ KB

# %%
df.head()
# Out:
#   Postcode      Borough                           Neighbourhood
# 0      M1B  Scarborough                          Rouge, Malvern
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                  Woburn
# 4      M1H  Scarborough                               Cedarbrae

# %%
df_M = pd.read_csv("Canadian Postal Codes_M.csv")
df_M.head()
# Out:
#   PostalCode  FSA   Latitude  Longitude   Place Name FSA1  FSA-Province  \
# 0     M1B0A1  M1B  43.686504 -79.279742  Scarborough    M            35
# 1     M1B0A2  M1B  43.816416 -79.227300  Scarborough    M            35
# 2     M1B0B2  M1B  43.806686 -79.194353  Scarborough    M            35
# 3     M1B1A1  M1B  43.797724 -79.227187  Scarborough    M            35
# 4     M1B1A2  M1B  43.798343 -79.227464  Scarborough    M            35
#
#   AreaType
# 0    Urban
# 1    Urban
# 2    Urban
# 3    Urban
# 4    Urban

# %%
# define the dataframe columns
column_names = ['Postcode','Borough', 'Neighbourhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood, Latitude, Longitude]
# Index: []

# %%
for index, row in df.iterrows():
    for index1, row1 in df_M.iterrows():
        if row['Postcode'] == row1['FSA']:
            neighborhoods = neighborhoods.append({'Postcode' : row['Postcode'],
                                        'Borough': row['Borough'],
                                        'Neighbourhood': row['Neighbourhood'],
                                        'Latitude': row1['Latitude'],
                                        'Longitude': row1['Longitude']}, ignore_index=True)    
            break

# %%
neighborhoods
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
neighborhoods.to_csv("Toronto_Latitude_Longitude.csv")

# %% [markdown]
# ## Notes:
# - In the first question, I have made a data frame with 3 columns: Postcode, Borough, Neighbourhood. Then I save this data frame to "Toronto.csv" file to reuse.
# ### In this file:
# - I read the file "Toronto.csv" to have the data frame about Toronto
# - Then, instead of using geocoder.google to get Latitude and Longitude for each Postcode, I use https://fusiontables.google.com/DataSource?docid=1H_cl-oyeG4FDwqJUTeI_aGKmmkJdPDzRNccp96M&hl=en_US&pli=1 to read, filter (Toronto, Ontario) PostalCode begin with "M" and save data to "Canadian Postal Codes_M.csv" (with columns: PostalCode, FSA, Latitude, Longitude, Place Name, FSA1, FSA-Province,AreaType). ** The reason I must to do that beacause the Internet somedays in Ho Chi Minh city is too slow, and interrupt so geocoder.google cannot work well.
# - In this file, I read "Canadian Postal Codes_M.csv" to have the data frame about Toronto with Latitude and Longitude.
# - After that, I make the new data frame **neighborhoods**, loop 2 data frame (with and without Latitude and Longitude) to compare and get value for the new row => append to **neighborhoods**
# - Now, I have all data which I need. And to save time, I write the **neighborhoods** dataframe to file "Toronto_Latitude_Longitude.csv" to reuse next question.
